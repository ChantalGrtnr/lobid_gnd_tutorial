# %%
import json
import requests
import pandas as pd
import rdflib

# %%
# create url with person-variable
person = 'Julius II.'
url = f"https://lobid.org/gnd/search?q={person}&format=json"
print(url)
# Out:
# https://lobid.org/gnd/search?q=Julius II.&format=json

# %%
# fetch url
# returns first 10 search results from url
response = requests.get(url)

# if fetching is successful (status_code 200)
if response.status_code == 200:
    #convert to json
    data = response.json()

# "pretty" print data with intent
print(json.dumps(data, indent=2))
# Out:
# {
#   "@context": "https://lobid.org/gnd/context.jsonld",
#   "id": "https://lobid.org/gnd/search?q=Julius%20II.&format=json",
#   "totalItems": 213,
#   "member": [
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4044561-6",
#           "label": "Papst"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4428342-8",
#           "label": "Albisola Superior"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "M\u00e4nnlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1513"
#       ],
#       "dateOfBirth": [
#         "1443"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4050471-2",
#           "label": "Rom"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pape"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Pontifex Romanus"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "surname": [
#             "DellaRovere"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Pontifex Maximus"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Papst"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pope"
#           ],
#           "personalName": [
#             "Jules"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "surname": [
#             "Della Rovere"
#           ],
#           "nameAddition": [
#             "Pope"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Pape"
#           ],
#           "personalName": [
#             "Jules"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Papa"
#           ],
#           "personalName": [
#             "Julio"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "P.M."
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "surname": [
#             "Della Rovere"
#           ],
#           "nameAddition": [
#             "Papst"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Papa"
#           ],
#           "personalName": [
#             "Iulius"
#           ]
#         },
#         {
#           "nameAddition": [
#             "Papst"
#           ],
#           "personalName": [
#             "Julio"
#           ]
#         },
#         {
#           "forename": [
#             "Julian"
#           ],
#           "prefix": [
#             "della"
#           ],
#           "surname": [
#             "Rovere"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Papa"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "P.M."
#           ],
#           "personalName": [
#             "Iulius"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "surname": [
#             "Della Rovere"
#           ],
#           "nameAddition": [
#             "Pape"
#           ]
#         },
#         {
#           "nameAddition": [
#             "della Rovere"
#           ],
#           "personalName": [
#             "Giuliano"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "nameAddition": [
#             "Pontifex Maximus"
#           ],
#           "personalName": [
#             "Iulius"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "prefix": [
#             "della"
#           ],
#           "surname": [
#             "Rovere"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pape"
#           ],
#           "personalName": [
#             "Julio"
#           ]
#         },
#         {
#           "forename": [
#             "Giuliano"
#           ],
#           "surname": [
#             "Della Rovere"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pope"
#           ],
#           "personalName": [
#             "Julius"
#           ]
#         },
#         {
#           "nameAddition": [
#             "della Rovere"
#           ],
#           "personalName": [
#             "Julien"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pape"
#           ],
#           "personalName": [
#             "Jules"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Papst"
#           ],
#           "personalName": [
#             "Jules"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Papst"
#           ],
#           "personalName": [
#             "Julio"
#           ]
#         },
#         {
#           "counting": [
#             "II"
#           ],
#           "nameAddition": [
#             "Pope"
#           ],
#           "personalName": [
#             "Julio"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "AuthorityResource",
#         "DifferentiatedPerson"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "gndSubjectCategory": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#3.6p",
#           "label": "Personen zu Kirchengeschichte, Systematischer und Praktischer Theologie, Kirche und Konfession"
#         },
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#8.4p",
#           "label": "Personen zu politischer Theorie, Milit\u00e4r"
#         },
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p",
#           "label": "Personen der Geschichte (Politiker und historische Pers\u00f6nlichkeiten)"
#         }
#       ],
#       "oldAuthorityNumber": [
#         "(DE-588a)159707765",
#         "(DE-588a)118714090",
#         "(DE-588)119724472",
#         "(DE-588a)119724472",
#         "(DE-588)159707765",
#         "(DE-588c)4096783-9"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-VA",
#           "label": "Vatikanstadt"
#         },
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-IT",
#           "label": "Italien"
#         }
#       ],
#       "deprecatedUri": [
#         "https://d-nb.info/gnd/159707765",
#         "https://d-nb.info/gnd/119724472"
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Papst seit 1503"
#       ],
#       "publication": [
#         "Breve de Causis Romanorum in Captiolio cognoscendis. - s.a.",
#         "Form vnd Wesen summarie begriffen der handl\u0169g zwischen Roemischer kayserlicher Maiestat ... 1509. (VD16 D 822)",
#         "Collectio Brevium et Bullarum Papae Iulii II.",
#         "Bulla contra aspirantes ad Papatum simoniace",
#         "Bulla Censurarum in singulos de Consilio et interdicti generalis ..",
#         "Bulla Annatarum prima",
#         "Breve ad Reges, Duces et Principes Christianos: in quo Continentur ..",
#         "Bulla Annatarum prima et secunda",
#         "Bulla edita contra Iohannem Bentivolum in civitate Bononiensi ..",
#         "Bulla Damnatio conciliabuli Pisani"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplin\u00e4re Allgemeinw\u00f6rter"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2022-12-01T17:04:09.000",
#         "id": "https://d-nb.info/gnd/118714090/about"
#       },
#       "gndIdentifier": "118714090",
#       "id": "https://d-nb.info/gnd/118714090",
#       "preferredName": "Julius II., Papst",
#       "wikipedia": [
#         {
#           "id": "https://de.wikipedia.org/wiki/Julius_II.",
#           "label": "https://de.wikipedia.org/wiki/Julius_II."
#         }
#       ],
#       "variantName": [
#         "Julius II, Pape",
#         "Jules II, Pape",
#         "Jules II, Pope",
#         "Jules II., Pape",
#         "Julio II, Pape",
#         "Della Rovere, Giuliano, Pope",
#         "Julius II, Papst",
#         "Julio II., Papa",
#         "Jules II, Papst",
#         "Iulius II., Papa",
#         "Julius II., Pontifex Romanus",
#         "Julio, Papst",
#         "Julius II., Pontifex Maximus",
#         "DellaRovere, Giuliano",
#         "Julius II., P.M.",
#         "Rovere, Julian della",
#         "Julien, della Rovere",
#         "Giuliano, della Rovere",
#         "Julio II, Papst",
#         "Della Rovere, Giuliano, Pape",
#         "Julius II., Papa",
#         "Iulius II., P.M.",
#         "Julius II, Pope",
#         "Della Rovere, Giuliano, Papst",
#         "Julio II, Pope",
#         "Iulius II., Pontifex Maximus",
#         "Rovere, Giuliano della",
#         "Della Rovere, Giuliano"
#       ],
#       "preferredNameEntityForThePerson": {
#         "counting": [
#           "II."
#         ],
#         "nameAddition": [
#           "Papst"
#         ],
#         "personalName": [
#           "Julius"
#         ]
#       },
#       "sameAs": [
#         {
#           "collection": {
#             "name": "Biblioth\u00e8que nationale de France",
#             "icon": "https://www.bnf.fr/themes/custom/bnfsi/favicon.ico",
#             "publisher": "Biblioth\u00e8que nationale de France",
#             "id": "http://www.wikidata.org/entity/Q19938912",
#             "abbr": "BNF"
#           },
#           "id": "http://catalogue.bnf.fr/ark:/12148/cb119549219"
#         },
#         {
#           "id": "http://id.loc.gov/rwo/agents/n80030746",
#           "collection": {
#             "icon": "http://www.loc.gov/favicon.ico",
#             "name": "NACO Authority File",
#             "publisher": "Library of Congress",
#             "id": "http://www.wikidata.org/entity/Q13219454",
#             "abbr": "LC"
#           }
#         },
#         {
#           "id": "http://viaf.org/viaf/51697938",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Historisches Lexikon der Schweiz (HLS)",
#             "icon": "https://www.hls-dhs-dss.ch/favicon.ico",
#             "publisher": "Historisches Lexikon der Schweiz (HLS)",
#             "id": "http://www.wikidata.org/entity/Q642074",
#             "abbr": "CH_HLS"
#           },
#           "id": "http://www.hls-dhs-dss.ch/textes/d/D18418.php"
#         },
#         {
#           "id": "http://www.wikidata.org/entity/Q80516",
#           "collection": {
#             "icon": "https://www.wikidata.org/static/favicon/wikidata.ico",
#             "name": "Wikidata",
#             "publisher": "Wikimedia Foundation Inc.",
#             "id": "http://www.wikidata.org/entity/Q2013",
#             "abbr": "WIKIDATA"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/118714090/about"
#         },
#         {
#           "id": "https://d-nb.info/gnd/119724472",
#           "collection": {
#             "icon": "http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           }
#         },
#         {
#           "id": "https://d-nb.info/gnd/159707765",
#           "collection": {
#             "icon": "http://www.dnb.de/SiteGlobals/StyleBundles/Bilder/favicon.png?__blob=normal&v=1",
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           }
#         },
#         {
#           "id": "https://dbpedia.org/resource/Pope_Julius_II",
#           "collection": {
#             "id": "https://dbpedia.org"
#           }
#         },
#         {
#           "collection": {
#             "name": "Wikipedia (Deutsch)",
#             "icon": "https://de.wikipedia.org/static/favicon/wikipedia.ico",
#             "publisher": "Wikimedia Foundation Inc.",
#             "id": "http://www.wikidata.org/entity/Q48183",
#             "abbr": "dewiki"
#           },
#           "id": "https://de.wikipedia.org/wiki/Julius_II."
#         },
#         {
#           "collection": {
#             "name": "Wikipedia (English)",
#             "icon": "https://en.wikipedia.org/static/favicon/wikipedia.ico",
#             "publisher": "Wikimedia Foundation Inc.",
#             "id": "http://www.wikidata.org/entity/Q328",
#             "abbr": "enwiki"
#           },
#           "id": "https://en.wikipedia.org/wiki/Pope_Julius_II"
#         },
#         {
#           "id": "https://isni.org/isni/0000000121326761",
#           "collection": {
#             "id": "https://isni.org"
#           }
#         },
#         {
#           "collection": {
#             "name": "Kalliope Verbundkatalog",
#             "icon": "https://kalliope-verbund.info/img/favicon.ico",
#             "publisher": "Staatsbibliothek zu Berlin - Preu\u00dfischer Kulturbesitz",
#             "id": "https://kalliope-verbund.info",
#             "abbr": "DE-611"
#           },
#           "id": "https://kalliope-verbund.info/gnd/118714090"
#         },
#         {
#           "collection": {
#             "name": "Archivportal-D",
#             "icon": "https://www.archivportal-d.de/favicon.ico",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "id": "https://www.archivportal-d.de",
#             "abbr": "ARCHIV-D"
#           },
#           "id": "https://www.archivportal-d.de/person/gnd/118714090"
#         },
#         {
#           "collection": {
#             "name": "Deutsche Digitale Bibliothek",
#             "icon": "https://www.deutsche-digitale-bibliothek.de/favicon.ico",
#             "publisher": "Deutsche Digitale Bibliothek",
#             "id": "http://www.wikidata.org/entity/Q621630",
#             "abbr": "DDB"
#           },
#           "id": "https://www.deutsche-digitale-bibliothek.de/person/gnd/118714090"
#         },
#         {
#           "collection": {
#             "name": "Digitaler Portraitindex der druckgraphischen Bildnisse der Fr\u00fchen Neuzeit",
#             "icon": "https://www.portraitindex.de/favicon.ico",
#             "publisher": "Deutsches Dokumentationszentrum f\u00fcr Kunstgeschichte - Bildarchiv Foto Marburg",
#             "id": "https://www.portraitindex.de",
#             "abbr": "Portraitindex"
#           },
#           "id": "https://www.portraitindex.de/dokumente/pnd/118714090"
#         }
#       ],
#       "depiction": [
#         {
#           "thumbnail": "https://commons.wikimedia.org/wiki/Special:FilePath/Pope%20Julius%20II.jpg?width=270",
#           "id": "https://commons.wikimedia.org/wiki/Special:FilePath/Pope%20Julius%20II.jpg",
#           "url": "https://commons.wikimedia.org/wiki/File:Pope%20Julius%20II.jpg?uselang=de"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "personalName": [
#             "Julius Secundus Pontifex Maximus"
#           ]
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "AuthorityResource",
#         "Person"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "publication": [
#         "@Oratio ad Christum Opt. Max. pro Julio Secundo Ligure Pont. Max. a quodam bene docto et Christiano perscripta.. - 15XX",
#         "@Oratio ad Christum Opt. Max. pro Julio Secundo Ligure Pont. Max. a quodam bene docto et Christiano perscripta, .... - 1520"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-03-03T16:00:21.000",
#         "id": "https://d-nb.info/gnd/1122839928/about"
#       },
#       "gndIdentifier": "1122839928",
#       "id": "https://d-nb.info/gnd/1122839928",
#       "preferredName": "Julius II. Papa",
#       "variantName": [
#         "Julius Secundus Pontifex Maximus"
#       ],
#       "preferredNameEntityForThePerson": {
#         "personalName": [
#           "Julius II. Papa"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/44148389368810712468",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1122839928/about"
#         }
#       ]
#     },
#     {
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "publication": [
#         "Donatio Constantini Bartholomei pincerni de Montearduo ad Iulium II.. - 1505",
#         "@Donationis, quae Constantini dicitur Privilegium.. - 1520",
#         "@[Teils.] Fastorum libri 12. Quibus praemittitur Carmen ad Iulium II. Pontificem maximum. Carmen ad Leonem X. Pontificem maximum. Vita authoris, a s... - 1520"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-03-03T16:00:53.000",
#         "id": "https://d-nb.info/gnd/1122850379/about"
#       },
#       "gndIdentifier": "1122850379",
#       "id": "https://d-nb.info/gnd/1122850379",
#       "preferredName": "Julius II. Papa",
#       "type": [
#         "AuthorityResource",
#         "Person",
#         "DifferentiatedPerson"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "preferredNameEntityForThePerson": {
#         "personalName": [
#           "Julius II. Papa"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/216148389147010710593",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1122850379/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4003157-3",
#           "label": "Arzt"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "M\u00e4nnlich"
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "Person",
#         "DifferentiatedPerson"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "oldAuthorityNumber": [
#         "(DE-588a)116940069"
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XD-US",
#           "label": "USA"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "New York (Wirkungsort)"
#       ],
#       "periodOfActivity": [
#         "1905"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplin\u00e4re Allgemeinw\u00f6rter"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2008-04-05T23:17:39.000",
#         "id": "https://d-nb.info/gnd/116940069/about"
#       },
#       "gndIdentifier": "116940069",
#       "id": "https://d-nb.info/gnd/116940069",
#       "preferredName": "Hoffmann, Julius, II",
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Julius"
#         ],
#         "surname": [
#           "Hoffmann"
#         ],
#         "nameAddition": [
#           "II"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/32761035",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/116940069/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "dateOfDeath": [
#         "1593"
#       ],
#       "dateOfBirth": [
#         "1547"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4801197-6",
#           "label": "Stetteldorf am Wagram"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "counting": [
#             "II."
#           ],
#           "forename": [
#             "Julius Pr\u00fcschenk"
#           ],
#           "prefix": [
#             "von"
#           ],
#           "surname": [
#             "Hardegg"
#           ]
#         },
#         {
#           "counting": [
#             "II."
#           ],
#           "forename": [
#             "Julius"
#           ],
#           "surname": [
#             "Pr\u00fcschenk von Hardegg"
#           ]
#         }
#       ],
#       "familialRelationship": [
#         {
#           "id": "https://d-nb.info/gnd/1185521887",
#           "label": "Hardegg, Julius von I."
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "DifferentiatedPerson",
#         "Person"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "gndSubjectCategory": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p",
#           "label": "Personen der Geschichte (Politiker und historische Pers\u00f6nlichkeiten)"
#         }
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-AT",
#           "label": "\u00d6sterreich"
#         }
#       ],
#       "titleOfNobility": [
#         {
#           "id": "https://d-nb.info/gnd/4021778-4",
#           "label": "Graf"
#         }
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#1",
#           "label": "Allgemeines, Interdisziplin\u00e4re Allgemeinw\u00f6rter"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2019-05-07T11:39:56.000",
#         "id": "https://d-nb.info/gnd/1185522085/about"
#       },
#       "broaderTermInstantial": [
#         {
#           "id": "https://d-nb.info/gnd/4000464-8",
#           "label": "Adel"
#         }
#       ],
#       "gndIdentifier": "1185522085",
#       "id": "https://d-nb.info/gnd/1185522085",
#       "preferredName": "Hardegg, Julius von II.",
#       "variantName": [
#         "Pr\u00fcschenk von Hardegg, Julius II.",
#         "Hardegg, Julius Pr\u00fcschenk von II."
#       ],
#       "preferredNameEntityForThePerson": {
#         "counting": [
#           "II."
#         ],
#         "forename": [
#           "Julius"
#         ],
#         "prefix": [
#           "von"
#         ],
#         "surname": [
#           "Hardegg"
#         ]
#       },
#       "hasParent": [
#         {
#           "id": "https://d-nb.info/gnd/1185521887",
#           "label": "Hardegg, Julius von I."
#         }
#       ],
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/4254155769092027880001",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1185522085/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "personalName": [
#             "Julius Bapst"
#           ]
#         }
#       ],
#       "type": [
#         "Person",
#         "DifferentiatedPerson",
#         "AuthorityResource"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "publication": [
#         "@Von dem gewalt und haupt der kirchen. - 1513"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-03-03T16:01:08.000",
#         "id": "https://d-nb.info/gnd/1122854420/about"
#       },
#       "gndIdentifier": "1122854420",
#       "id": "https://d-nb.info/gnd/1122854420",
#       "preferredName": "Julius II. Papa",
#       "variantName": [
#         "Julius Bapst"
#       ],
#       "preferredNameEntityForThePerson": {
#         "personalName": [
#           "Julius II. Papa"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/27148389124510710202",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1122854420/about"
#         }
#       ]
#     },
#     {
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "personalName": [
#             "Iulius"
#           ]
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "DifferentiatedPerson",
#         "Person"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "publication": [
#         "@Iulius. - 1513"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2017-03-03T16:01:08.000",
#         "id": "https://d-nb.info/gnd/1122854447/about"
#       },
#       "gndIdentifier": "1122854447",
#       "id": "https://d-nb.info/gnd/1122854447",
#       "preferredName": "Julius II. Papa",
#       "variantName": [
#         "Iulius"
#       ],
#       "preferredNameEntityForThePerson": {
#         "personalName": [
#           "Julius II. Papa"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/242148389153010710893",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1122854447/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4138343-6",
#           "label": "Verleger"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "M\u00e4nnlich"
#         }
#       ],
#       "type": [
#         "DifferentiatedPerson",
#         "AuthorityResource",
#         "Person"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "periodOfActivity": [
#         "1819-1849"
#       ],
#       "affiliation": [
#         {
#           "id": "https://d-nb.info/gnd/1072916134",
#           "label": "Julius Helbig (Firma)"
#         }
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2024-04-16T16:37:51.000",
#         "id": "https://d-nb.info/gnd/1073364208/about"
#       },
#       "gndIdentifier": "1073364208",
#       "id": "https://d-nb.info/gnd/1073364208",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4001409-5",
#           "label": "Altenburg (Th\u00fcringen)"
#         }
#       ],
#       "preferredName": "Helbig, Julius, II",
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Julius"
#         ],
#         "surname": [
#           "Helbig"
#         ],
#         "nameAddition": [
#           "II"
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/316514716",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1073364208/about"
#         }
#       ]
#     },
#     {
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#ZZ",
#           "label": "Land unbekannt"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#notKnown",
#           "label": "Unbekannt"
#         }
#       ],
#       "publication": [
#         "Stanislai Orichovii Rutheni, De lege coelibatus, contra Syricium in concilio habita oratio. Eiusdem Stanislai ad Julium Tertium pont. max. supplicat... - 1551"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#6",
#           "label": "Kultur, Erziehung, Bildung, Wissenschaft"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2018-05-06T00:01:25.000",
#         "id": "https://d-nb.info/gnd/1157906265/about"
#       },
#       "gndIdentifier": "1157906265",
#       "id": "https://d-nb.info/gnd/1157906265",
#       "preferredName": "Julius III.",
#       "type": [
#         "Person",
#         "AuthorityResource",
#         "DifferentiatedPerson"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "preferredNameEntityForThePerson": {
#         "personalName": [
#           "Julius III."
#         ]
#       },
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/3154159478279327990003",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1157906265/about"
#         }
#       ]
#     },
#     {
#       "professionOrOccupation": [
#         {
#           "id": "https://d-nb.info/gnd/4034399-6",
#           "label": "Landwirt"
#         },
#         {
#           "id": "https://d-nb.info/gnd/4196107-9",
#           "label": "Gutsherr"
#         }
#       ],
#       "placeOfBirth": [
#         {
#           "id": "https://d-nb.info/gnd/4041712-8",
#           "label": "Neubrandenburg"
#         }
#       ],
#       "gender": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/gender#male",
#           "label": "M\u00e4nnlich"
#         }
#       ],
#       "dateOfDeath": [
#         "1901-07-21"
#       ],
#       "dateOfBirth": [
#         "1841-11-01"
#       ],
#       "placeOfDeath": [
#         {
#           "id": "https://d-nb.info/gnd/4041712-8",
#           "label": "Neubrandenburg"
#         }
#       ],
#       "variantNameEntityForThePerson": [
#         {
#           "forename": [
#             "Georg Friedrich Julius"
#           ],
#           "surname": [
#             "Moncke"
#           ]
#         },
#         {
#           "forename": [
#             "J."
#           ],
#           "surname": [
#             "Moncke"
#           ]
#         }
#       ],
#       "familialRelationship": [
#         {
#           "id": "https://d-nb.info/gnd/1051944880",
#           "label": "Moncke, Friedrich (II.)"
#         },
#         {
#           "id": "https://d-nb.info/gnd/1228090238",
#           "label": "Moncke, Franz"
#         },
#         {
#           "id": "https://d-nb.info/gnd/1251370063",
#           "label": "Moncke, Georg (IV.)"
#         },
#         {
#           "id": "https://d-nb.info/gnd/1251356818",
#           "label": "Moncke, Georg (II.)"
#         }
#       ],
#       "type": [
#         "AuthorityResource",
#         "Person",
#         "DifferentiatedPerson"
#       ],
#       "@context": "https://lobid.org/gnd/context.jsonld",
#       "relatedPlaceOrGeographicName": [
#         {
#           "id": "https://d-nb.info/gnd/4038197-3",
#           "label": "Mecklenburg"
#         }
#       ],
#       "geographicAreaCode": [
#         {
#           "id": "https://d-nb.info/standards/vocab/gnd/geographic-area-code#XA-DE",
#           "label": "Deutschland"
#         }
#       ],
#       "biographicalOrHistoricalInformation": [
#         "Gr\u00fcnder, Gutsbesitzer / Monckeshof [Neubrandenburg]"
#       ],
#       "describedBy": {
#         "descriptionLevel": {
#           "id": "https://d-nb.info/standards/vocab/gnd/description-level#3",
#           "label": "Religion"
#         },
#         "license": {
#           "id": "http://creativecommons.org/publicdomain/zero/1.0/",
#           "label": "http://creativecommons.org/publicdomain/zero/1.0/"
#         },
#         "dateModified": "2022-02-08T18:22:15.000",
#         "id": "https://d-nb.info/gnd/1251374581/about"
#       },
#       "gndIdentifier": "1251374581",
#       "id": "https://d-nb.info/gnd/1251374581",
#       "placeOfActivity": [
#         {
#           "id": "https://d-nb.info/gnd/4041712-8",
#           "label": "Neubrandenburg"
#         }
#       ],
#       "preferredName": "Moncke, Julius",
#       "hasSibling": [
#         {
#           "id": "https://d-nb.info/gnd/1051944880",
#           "label": "Moncke, Friedrich (II.)"
#         },
#         {
#           "id": "https://d-nb.info/gnd/1251370063",
#           "label": "Moncke, Georg (IV.)"
#         }
#       ],
#       "variantName": [
#         "Moncke, Georg Friedrich Julius",
#         "Moncke, J."
#       ],
#       "preferredNameEntityForThePerson": {
#         "forename": [
#           "Julius"
#         ],
#         "surname": [
#           "Moncke"
#         ]
#       },
#       "hasParent": [
#         {
#           "id": "https://d-nb.info/gnd/1251356818",
#           "label": "Moncke, Georg (II.)"
#         }
#       ],
#       "sameAs": [
#         {
#           "id": "http://viaf.org/viaf/5881164479563126210004",
#           "collection": {
#             "icon": "http://viaf.org/viaf/images/viaf.ico",
#             "name": "Virtual International Authority File (VIAF)",
#             "publisher": "OCLC",
#             "id": "http://www.wikidata.org/entity/Q54919",
#             "abbr": "VIAF"
#           }
#         },
#         {
#           "collection": {
#             "name": "Gemeinsame Normdatei (GND) im Katalog der Deutschen Nationalbibliothek",
#             "icon": "https://www.dnb.de/SiteGlobals/Frontend/DNBWeb/Images/favicon.png?__blob=normal&v=4",
#             "publisher": "Deutsche Nationalbibliothek",
#             "id": "http://www.wikidata.org/entity/Q36578",
#             "abbr": "DNB"
#           },
#           "id": "https://d-nb.info/gnd/1251374581/about"
#         }
#       ]
#     }
#   ],
#   "aggregation": {
#     "gndSubjectCategory.id": [
#       {
#         "key": "https://d-nb.info/standards/vocab/gnd/gnd-sc#16.5p",
#         "doc_count": 24
#       },
#       {
#         "key": "https://d-nb.info/standards/vocab/gnd/gnd-sc#13.4p",
#         "doc_count": 10
#       },
#       {
#         "key": "https://d-nb.info/standards/vocab/gnd/gnd-sc#3.6p",
#         "doc_count": 9
#       },
#       {
#         "key": "https://d-nb.info/standards/vocab/gnd/gnd-sc
#       },
#       {
#         "key": "1865-05-12",
#         "doc_count": 1
#       },
#       {
#         "key": "1868-10-05",
#         "doc_count": 1
#       },
#       {
#         "key": "1869-01-12",
#         "doc_count": 1
#       },
#       {
#         "key": "1871",
#         "doc_count": 1
#       },
#       {
#         "key": "1872-06-16",
#         "doc_count": 1
#       },
#       {
#         "key": "1873",
#         "doc_count": 1
#       },
#       {
#         "key": "1873-10-17",
#         "doc_count": 1
#       },
#       {
#         "key": "1873-12-29",
#         "doc_count": 1
#       },
#       {
#         "key": "1877-05-21",
#         "doc_count": 1
#       },
#       {
#         "key": "1877-05-29",
#         "doc_count": 1
#       },
#       {
#         "key": "1880-04-15",
#         "doc_count": 1
#       },
#       {
#         "key": "1881-09-14",
#         "doc_count": 1
#       },
#       {
#         "key": "1888-03-23",
#         "doc_count": 1
#       },
#       {
#         "key": "1888-07-12",
#         "doc_count": 1
#       },
#       {
#         "key": "1905",
#         "doc_count": 1
#       },
#       {
#         "key": "1923-06-20",
#         "doc_count": 1
#       },
#       {
#         "key": "1947-10-03",
#         "doc_count": 1
#       },
#       {
#         "key": "1948",
#         "doc_count": 1
#       },
#       {
#         "key": "1958",
#         "doc_count": 1
#       },
#       {
#         "key": "1961",
#         "doc_count": 1
#       },
#       {
#         "key": "1964",
#         "doc_count": 1
#       },
#       {
#         "key": "1969",
#         "doc_count": 1
#       },
#       {
#         "key": "1973",
#         "doc_count": 1
#       },
#       {
#         "key": "1976",
#         "doc_count": 1
#       },
#       {
#         "key": "1976-10-29",
#         "doc_count": 1
#       },
#       {
#         "key": "1977",
#         "doc_count": 1
#       },
#       {
#         "key": "1979",
#         "doc_count": 1
#       },
#       {
#         "key": "1982",
#         "doc_count": 1
#       },
#       {
#         "key": "1983",
#         "doc_count": 1
#       },
#       {
#         "key": "1986",
#         "doc_count": 1
#       },
#       {
#         "key": "1989",
#         "doc_count": 1
#       }
#     ],
#     "type": [
#       {
#         "key": "Person",
#         "doc_count": 179
#       },
#       {
#         "key": "DifferentiatedPerson",
#         "doc_count": 171
#       },
#       {
#         "key": "Work",
#         "doc_count": 17
#       },
#       {
#         "key": "CorporateBody",
#         "doc_count": 10
#       },
#       {
#         "key": "RoyalOrMemberOfARoyalHouse",
#         "doc_count": 8
#       },
#       {
#         "key": "BuildingOrMemorial",
#         "doc_count": 4
#       },
#       {
#         "key": "Expression",
#         "doc_count": 4
#       },
#       {
#         "key": "PlaceOrGeographicName",
#         "doc_count": 4
#       },
#       {
#         "key": "ConferenceOrEvent",
#         "doc_count": 3
#       },
#       {
#         "key": "MusicalWork",
#         "doc_count": 1
#       },
#       {
#         "key": "OrganOfCorporateBody",
#         "doc_count": 1
#       },
#       {
#         "key": "ReligiousCorporateBody",
#         "doc_count": 1
#       }
#     ]
#   }
# }

# %%
# get gnd-number from first member in results
# acces key with get() --> safer, does not return KeyError if empty instead of data['member']
members = data.get('member', [])

# %%
# Fetch person by name,
# filter by type:Person and professionOrOccupation

#person = 'Julius II.'
#profession = 'Papst'
person = 'Marquard Bermann'
profession = 'Bischof'

url = f"https://lobid.org/gnd/search?q=preferredName:{person}" \
      f"&filter=professionOrOccupation.label:{profession} " \
      f"&filter=type:Person" \
      f"&format=json"

#url = f"https://lobid.org/gnd/search?q={person}&format=json"

print(url)
# Out:
# https://lobid.org/gnd/search?q=preferredName:Marquard Bermann&filter=professionOrOccupation.label:Bischof OR professionOrOccupationAsLiteral:Bischof&filter=type:Person&format=json

# %%
member = members[0]
member_gnd = member.get('gndIdentifier', [])
print(member_gnd)
# Out:
# 118714090

# %%
# get label of gender
gender_labels = [g.get('label', "") for g in member.get('gender', [])]
gender_labels = ",".join(gender_labels)
print(gender_labels)
# Out:
# Männlich

# %%
# Create a list of person names
# Bonifatius ist ein gutes Beispiel für: Einschränken nach Person
# Julius II mehrere Ergebnisse
names = ['Marquard Bermann', 'Bonifatius IX.', 'Julius II.']
professions = ['Bischof', 'Papst', 'Papst']

# Combine into a dictionary
persons = dict(zip(names, professions))

# %%
# initialize empty list
persons_data = []

# loop over persons and fetch data
for person, profession in persons.items():

    print(f"fetch data for person: {person}, profession: {profession}")

    # build url
    url = f"https://lobid.org/gnd/search?q=preferredName:{person}" \
          f"&filter=professionOrOccupation.label:{profession} " \
          f"OR professionOrOccupationAsLiteral:{profession}" \
          f"&filter=type:Person" \
          f"&format=json"

    # fetch url
    response = requests.get(url)

    # if response is available: extract data
    if response.status_code == 200:

        # convert to json
        data = response.json()

        # process results for personname,
        # note: one person can have multiple results (member-entries)
        members = data.get('member', [])

        if len(members) > 0:
            # process only first 5 results (by default, 10 are returned)
            for member in members:

                # append fetched data
                persons_data.append({
                    'input_name' : person,
                    'person_name':member.get('preferredName', []),
                    'gnd': member.get('gndIdentifier', []),
                    'member_gnd_link' : member.get('id', []),
                    'gender' : ",".join([i.get('label', "") for i in member.get('gender', [])]),
                    'date_death' : ",".join(member.get('dateOfDeath', [])),
                    'date_birth' : ",".join(member.get('dateOfBirth', [])),
                    'profession': ",".join(member.get('professionOrOccupationAsLiteral', []))
                }
                )

        # if no members available: add person name to list
        else:
            # add only person name
            persons_data.append({
                'input_name': person,
            })

# convert to pandas dataframe
persons_data = pd.DataFrame(persons_data)

persons_data
# Out:
# fetch data for person: Marquard Bermann, profession: Bischof
# fetch data for person: Bonifatius IX., profession: Papst
# fetch data for person: Julius II., profession: Papst
#          input_name            person_name         gnd  \
# 0  Marquard Bermann      Bermann, Marquard  1150194170
# 1    Bonifatius IX.  Bonifatius IX., Papst   118661469
# 2        Julius II.      Julius II., Papst   118714090
# 3        Julius II.     Julius III., Papst   118955314
#
#                     member_gnd_link    gender  date_death date_birth  \
# 0  https://d-nb.info/gnd/1150194170  Männlich  1378-09-17
# 1   https://d-nb.info/gnd/118661469  Männlich        1404       1350
# 2   https://d-nb.info/gnd/118714090  Männlich        1513       1443
# 3   https://d-nb.info/gnd/118955314  Männlich        1555       1487
#
#                profession
# 0  Domherr,Bischof,Propst
# 1
# 2
# 3

# %%
# select top entry for persons
persons_data_top = persons_data.groupby('input_name').first().reset_index()

# %%
# Parse json-ld as graph
graph = rdflib.Graph()
graph.parse(data=data, format="json-ld")

# Print extracted data
print(graph)

# context files?
#context_url = "https://lobid.org/gnd/context.jsonld"
#context_response = requests.get(context_url)
#context = context_response.json()
# Out:
# [a rdfg:Graph;rdflib:storage [a rdflib:Store;rdfs:label 'Memory']].

# %%
# SPARQL query to get all gndIdentifiers
query = """
    SELECT ?gndIdentifier WHERE {
        # ?subject <https://d-nb.info/standards/elementset/gnd#gndIdentifier> ?gndIdentifier .
    }
"""

# Execute the query on the graph
results = graph.query(query)

# Iterate over the results and print gndIdentifiers
for row in results:
    print(f"gndIdentifier: {row[0]}")
# Out:
# gndIdentifier: 118714090
# gndIdentifier: 1122839928
# gndIdentifier: 1122850379
# gndIdentifier: 116940069
# gndIdentifier: 1185522085
# gndIdentifier: 1122854420
# gndIdentifier: 1122854447
# gndIdentifier: 1073364208
# gndIdentifier: 1157906265
# gndIdentifier: 1251374581

# %%
# SPAQRL-Query
query = """
    SELECT ?personName ?gndIdentifier ?gender ?dateOfDeath ?dateOfBirth ?profession WHERE {
        # ?subject a <https://d-nb.info/standards/elementset/gnd#Person> .

        # Get preferredName
        # ?subject <https://d-nb.info/standards/elementset/gnd#preferredName> ?personName .

        # Get gndIdentifier
        # ?subject <https://d-nb.info/standards/elementset/gnd#gndIdentifier> ?gndIdentifier .

        # Get gender (assuming it's under gender or similar property)
        # ?subject <https://d-nb.info/standards/elementset/gnd#gender> ?gender .

        # Get dateOfDeath
        # ?subject <https://d-nb.info/standards/elementset/gnd#dateOfDeath> ?dateOfDeath .

        # Get dateOfBirth
        # ?subject <https://d-nb.info/standards/elementset/gnd#dateOfBirth> ?dateOfBirth .

        # Get profession
        # ?subject <https://d-nb.info/standards/elementset/gnd#professionOrOccupation> ?profession .

    }
"""

# Execute the query on the graph
results = graph.query(query)

# Iterate over the results and collect the data
members = []
for row in results:
    member = {
        'person_name_result': row['personName'].value if row['personName'] else "",
        'gnd': row['gndIdentifier'],
        'gender': row['gender'] if row['gender'] else "",
        'date_death': row['dateOfDeath'].value if row['dateOfDeath'] else "",
        'date_birth': row['dateOfBirth'].value if row['dateOfBirth'] else "",
        'profession': row['profession'] if row['profession'] else "",
    }
    members.append(member)

# Print the extracted members' data
for member in members:
    print(member)
# Out:
# {'person_name_result': 'Julius II., Papst', 'gnd': rdflib.term.Literal('118714090'), 'gender': rdflib.term.URIRef('https://d-nb.info/standards/vocab/gnd/gender#male'), 'date_death': '1513', 'date_birth': '1443', 'profession': rdflib.term.URIRef('https://d-nb.info/gnd/4044561-6')}
# {'person_name_result': 'Julius III., Papst', 'gnd': rdflib.term.Literal('118955314'), 'gender': rdflib.term.URIRef('https://d-nb.info/standards/vocab/gnd/gender#male'), 'date_death': '1555', 'date_birth': '1487', 'profession': rdflib.term.URIRef('https://d-nb.info/gnd/4044561-6')}
